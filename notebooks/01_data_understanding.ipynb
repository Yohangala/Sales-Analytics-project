# %%
import pandas as pd
import numpy as np

file_path = "../data/raw/Global Superstore Data.xlsx"

# %%
xls = pd.ExcelFile(file_path)
xls.sheet_names
# Out:
# ['Orders', 'Returns', 'People']

# %%
df = pd.read_excel(file_path, sheet_name="Orders")

df.head()

# %%
df.shape
df.info()
